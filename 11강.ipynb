# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([2,4,2,6,8,3])

# %%
nums = np.arange(5)
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
plt.plot(nums,nums)
plt.plot(nums, nums*nums)
plt.plot(nums, nums**3)

# %%
plt.style.use('seaborn')

# %%
plt.plot(nums,nums)
plt.plot(nums, nums*nums)
plt.plot(nums, nums**3)

# %%
plt.style.use('ggplot')

# %%
plt.plot(nums,nums, color="olive",lw=4)
plt.plot(nums, nums*nums, color="#ff96b6", lw=4)
plt.plot(nums, nums**3, color="#ff9f43", lw=4)

# %%
plt.plot(nums,nums, color="olive",lw=4, linestyle="dashed")
plt.plot(nums, nums*nums, color="#ff96b6", lw=4, linestyle="dotted")
plt.plot(nums, nums**3, color="#ff9f43", lw=4, linestyle="-.")

# %% [markdown]
# Bar Plots

# %% [markdown]
# 'Spinach', 'Turnip', 'Rhubarb', 'Broccoli', 'Kale'

# %%
died = [10,25,5,30,21]
germinated = [74,88,56,69,59]
#::: plt.plot  - 선으로 만들어진 그래프 
#::: plt.bar - 막대로 만들어진 그래프

# %%
plants = ['Spinach', 'Turnip', 'Rhubarb', 'Broccoli', 'Kale']
died = [10,25,5,30,21]
germinated = [74,88,56,69,59]
plt.figure(figsize=(6,6))
plt.bar(plants, germinated, color = "orchid")
plt.title("Germination Rates")
plt.ylabel("Number Of seeldings")
# Out:
# Text(0, 0.5, 'Number Of seeldings')

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, died, color = "red")
plt.title("Failure Rates")
plt.ylabel("Number Of Dead Seeding")
# Out:
# Text(0, 0.5, 'Number Of Dead Seeding')

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, died, color = "#3498db")
plt.bar(plants, germinated, width=0.4, color="#2ecc71", align="edge")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, died, color="#3498db", bottom=germinated, label="Failed Seedlings")
plt.bar(plants, germinated, color="#2ecc71", label="Germinated Seedlings")
plt.legend()
plt.title("Greenhouse Seedlings")
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, died, color="#3498db", bottom=germinated, label="Failed Seedlings")
plt.bar(plants, germinated, color="#2ecc71", label="Germinated Seedlings")
plt.legend(shadow=True, frameon=True, facecolor="white")
#plt.legend()
plt.title("Greenhouse Seedlings")
plt.show()

# %%
plt.hist([1,1,2,3,3,3,3,3,4,4,4,5,1,2,1,2,1,2,3,4])
# Out:
# (array([5., 0., 4., 0., 0., 6., 0., 4., 0., 1.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Errors = “coerce” 라고 표기하면 숫자가 아닌 데이터를 NaN으로 설정하여 반환한다.
# Pd.to_numeric 은 데이터를 숫자 형식으로 표출하라는 것.

# %%
nums = np.random.randn(100)
plt.hist(nums)
# Out:
# (array([ 1.,  3.,  4., 19., 23., 25., 13.,  5.,  2.,  5.]),
#  array([-2.86880466, -2.31542321, -1.76204176, -1.20866031, -0.65527886,
#         -0.10189742,  0.45148403,  1.00486548,  1.55824693,  2.11162837,
#          2.66500982]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
titanic = pd.read_csv("data/titanic.csv")

titanic["age"] = pd.to_numeric(titanic["age"], errors = "coerce")
plt.hist(titanic["age"])
# 타이타닉에 탑승한 승객들의 나이를 x축에 표시하고, y축은 승객의 수를 의미한다
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.1667 ,  8.15003, 16.13336, 24.11669, 32.10002, 40.08335,
#         48.06668, 56.05001, 64.03334, 72.01667, 80.     ]),
#  <BarContainer object of 10 artists>)

# %%
titanic["pclass"] = pd.to_numeric(titanic["pclass"], errors="coerce")
plt.hist(titanic["pclass"])
# Out:
# (array([323.,   0.,   0.,   0.,   0., 277.,   0.,   0.,   0., 709.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
heights = [137,140,142,145,147,150,152,155,157,160]
f_weights = [28.5,30.8,32.6,34.9,36.4,39,49.8,43.1,44.9,47.2]
m_weights = [34.9,38.1,33.5,35.8,46.7,42.8,43.1,45.8,50.8,58.9]

# %%
plt.plot(heights,f_weights, marker="*", label="Female")
plt.plot(heights,m_weights, marker="d", label="Male")
plt.legend()
plt.xlabel("Height(cm)")
plt.ylabel("Weight(kg)")
# Out:
# Text(0, 0.5, 'Weight(kg)')

# %% [markdown]
# 남녀의 몸무게가 키에 따라 어떻게 상관관계를 갖는지 그래프로 드러내고자 함.
# 여자의 경우 키에 따른 몸무게의 변화가 일정하게 늘어나지만,
# 남자의 경우, 140~ 145구간과 147에서 155구간이 키에 비해 저체중 양상이 나타납니다.

# %%
plt.scatter(heights,f_weights, marker="*", label="Female")
plt.scatter(heights,m_weights, marker="d", label="Male")
plt.legend()
plt.xlabel("Height(cm)")
plt.ylabel("Weight(kg)")
# Out:
# Text(0, 0.5, 'Weight(kg)')

# %%
first_class = titanic[titanic["pclass"] ==1]["age"]
second_class =titanic[titanic["pclass"]==2]["age"]
third_class = titanic[titanic["pclass"]==3]["age"]

plt.figure(figsize = (10, 4))
ax = plt.subplot(1, 3, 1)
plt.hist(first_class, label='1st Class', color="#f1c40f", bins=20)
plt.title("1st Class")
plt.subplot(1,3,2,sharey=ax)
plt.hist(second_class, label="2nd Class", color="#3498db", bins=20)
plt.title("2nd Class")
plt.subplot(1,3,3,sharey=ax)
plt.hist(third_class, label="3rd Class", color="#e74c3c", bins=20)
plt.title("3rd Class")
# Out:
# Text(0.5, 1.0, '3rd Class')

# %% [markdown]
# Bins의 기능은 무엇일까요?
# Bins값을 높이면 높일수록 데이터의 정확도가 높아지고 세밀해집니다. X축 간격이 좋아집니다.

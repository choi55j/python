# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
nba = pd.read_csv("data/nba.csv", low_memory = False)
nba.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
nba.tail(5)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba[['Salary','Team','Name']].tail(5)
# Out:
#         Salary       Team          Name
# 453  2433333.0  Utah Jazz  Shelvin Mack
# 454   900000.0  Utah Jazz     Raul Neto
# 455  2900000.0  Utah Jazz  Tibor Pleiss
# 456   947276.0  Utah Jazz   Jeff Withey
# 457        NaN        NaN           NaN

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba['Weight in Kilograms']=nba['Weight']/2.20462

# %%
nba['Salary in Millions']=nba['Salary']/1000000
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  Weight in Kilograms  Salary in Millions
# ...

# %%
nba.dropna().tail(10)
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 442   Trevor Booker  Utah Jazz    33.0       PF  28.0    6-8   228.0
# 443      Trey Burke  Utah Jazz     3.0       PG  23.0    6-1   191.0
# 444      Alec Burks  Utah Jazz    10.0       SG  24.0    6-6   214.0
# 446  Derrick Favors  Utah Jazz    15.0       PF  24.0   6-10   265.0
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456     Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
#
#           College      Salary  Weight in Kilograms  Salary in Millions
# 442       Clemson   4775000.0           103.419183            4.775000
# ...

# %%
nba.dropna(how = "all", inplace = True)
nba.dropna(inplace = True)
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  Weight in Kilograms  Salary in Millions
# ...

# %%
nba.fillna(0)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  Weight in Kilograms  Salary in Millions
# ...

# %%
nba['Salary']=nba['Salary'].fillna(0, inplace = True)

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College Salary  Weight in Kilograms  Salary in Millions
# ...

# %%
nba['College'].fillna('None', inplace=True)

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba = pd.read_csv("data/nba.csv").dropna(how= "all")
nba['Salary'].fillna(0, inplace=True)
nba['College'].fillna('None', inplace=True)

# %%
nba.head(6)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University        None
# 3      Georgia State   1148640.0
# 4                  0   5000000.0
# 5                  0  12000000.0

# %% [markdown]
# dropna(how = “any”) : NaN이 하나라도 포함된 경우, 그 행을 지운다.     //  dropna(how = “all”) 모든 컬럼의 value가 없는 행을 지운다.

# %%
nba.dropna(how="any")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.dropna(how="all")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 35.7+ KB

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary       object
# dtype: object

# %%
nba['Salary']=nba['Salary'].astype('int')
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba['Number']=nba['Number'].astype('int')
nba['Age']=nba['Age'].astype('int')
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
# 종류가 몇 가지 인지
nba['Position'].nunique()
# Out:
# 5

# %%
nba = pd.read_csv("data/nba.csv")
nba.sort_values(['Salary'], ascending=False).tail(10)
# Out:
#                Name                    Team  Number Position   Age Height  \
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight                College  Salary
# 171   225.0                   Duke     NaN
# 264   180.0                   UCLA     NaN
# ...

# %%
nba.sort_values(['Salary'], ascending=True).head(5).sort_values(['Salary'], ascending=False)
# Out:
#                        Name                  Team  Number Position   Age  \
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
#
#     Height  Weight           College    Salary
# 175    6-5   179.0         Tennessee  111196.0
# 135    6-8   260.0  UC Santa Barbara   83397.0
# 291    6-5   220.0  UC Santa Barbara   55722.0
# 130   5-11   175.0          Missouri   55722.0
# 32     6-7   205.0               NaN   30888.0

# %%
nba.sort_values(['Salary'], ascending=False, na_position="first").tail()
# Out:
#                        Name                  Team  Number Position   Age  \
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
#
#     Height  Weight           College    Salary
# 175    6-5   179.0         Tennessee  111196.0
# 135    6-8   260.0  UC Santa Barbara   83397.0
# 291    6-5   220.0  UC Santa Barbara   55722.0
# 130   5-11   175.0          Missouri   55722.0
# 32     6-7   205.0               NaN   30888.0

# %%
nba = pd.read_csv("data/nba.csv").dropna(how = "all")
nba["Salary"] = nba["Salary"].fillna(0).astype("int")
nba["Salary Rank"] = nba["Salary"].rank(ascending = False).astype("int")

# %%
nba.sort_values(by = "Salary", ascending = False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 264    Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 273   Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
#
#      Weight       College    Salary  Salary Rank
# ...

# %%
empl = pd.read_csv("data/employees.csv")

# %%
empl.head(10)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
empl.dtypes
# Out:
# First Name            object
# Gender                object
# Start Date            object
# Last Login Time       object
# Salary                 int64
# Bonus %              float64
# Senior Management     object
# Team                  object
# dtype: object

# %%
empl['Gender']=empl['Gender'].astype("category")
empl['Start Date']=empl['Start Date'].astype("datetime64[ns]")
empl['Last Login Time']=empl['Last Login Time'].astype("datetime64[ns]")
empl['Senior Management']=empl['Senior Management'].astype("bool")
empl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
df = pd.read_csv("data/employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
empl=empl[empl['Gender']=='Male']
empl[empl['Team']=='Marketing'].head(25)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2023-11-01 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2023-11-01 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2023-11-01 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2023-11-01 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2023-11-01 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2023-11-01 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2023-11-01 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2023-11-01 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2023-11-01 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2023-11-01 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2023-11-01 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2023-11-01 09:45:00   55281    4.935
# ...

# %%
mask1 = df["Gender"] == "Male"
mask2 = df["Team"] == "Marketing"
df[mask1 & mask2].head(25)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2023-11-01 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2023-11-01 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2023-11-01 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2023-11-01 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2023-11-01 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2023-11-01 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2023-11-01 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2023-11-01 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2023-11-01 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2023-11-01 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2023-11-01 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2023-11-01 09:45:00   55281    4.935
# ...

# %%
empl = pd.read_csv("data/employees.csv")

# %%
empl1 = empl['Gender']=="Female"
empl2 = empl['Team']=="Finance"
empl[empl1 | empl2]
# 역슬레쉬는 or을 대신한다
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# ..         ...     ...         ...             ...     ...      ...
# 990      Robin  Female   7/24/1987         1:35 PM  100765   10.982
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 993       Tina  Female   5/15/1997         3:53 PM   56450   19.040
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
#
#     Senior Management             Team
# 2               False          Finance
# 3                True          Finance
# ...

# %%
empl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
empl['Start Date']=empl['Start Date'].astype('datetime64[ns]')
empl['Gender']=empl['Gender'].astype("category")

# %%
mask1 = empl["Gender"] == "Male"
mask2 = empl["Team"] == "Client Services"
mask3 = empl["Start Date"] > "2016-06-01"
empl[(mask1 & mask2)|mask3]
# Out:
#       First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 4          Larry    Male 1998-01-24         4:47 PM  101004    1.389
# 15       Lillian  Female 2016-06-05         6:09 AM   59414    1.256
# 24          John    Male 1992-07-01        10:08 PM   97950   13.873
# 25           NaN    Male 2012-10-08         1:12 AM   37076   18.576
# 28         Terry    Male 1981-11-27         6:30 PM  124008   13.464
# 34         Jerry    Male 2004-01-10        12:56 PM   95734   19.096
# 39           NaN    Male 2016-01-29         2:33 AM  122173    7.797
# 82        Steven    Male 1980-03-30         9:20 PM   35095    8.379
# 85        Jeremy    Male 2008-02-01         8:50 AM  100238    3.887
# 98          Tina  Female 2016-06-16         7:47 PM  100705   16.961
# 102         Jack    Male 1997-01-12         5:51 AM  103902   12.159
# 128      Kenneth    Male 1987-08-25         9:16 PM  127654   16.439
# 163        Terry    Male 1990-09-03         9:15 PM   52226   19.135
# ...

# %%
msg1 = empl["Team"] == "Legal"
msg2 = empl["Team"] == "Product"
msg3 = empl["Team"] == "Sales"
empl[msg1|msg2|msg3]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18         1:35 AM  115163   10.125
# 6         Ruby  Female 1987-08-17         4:20 PM   65476   10.012
# 11       Julie  Female 1997-10-26         3:19 PM  102508   12.637
# 13        Gary    Male 2008-01-27        11:40 PM  109831    5.831
# 15     Lillian  Female 2016-06-05         6:09 AM   59414    1.256
# ..         ...     ...        ...             ...     ...      ...
# 981      James    Male 1993-01-15         5:19 PM  148985   19.280
# 985    Stephen     NaN 1983-07-10         8:10 PM   85668    1.909
# 989     Justin     NaN 1991-02-10         4:58 PM   38344    3.794
# 997    Russell    Male 2013-05-20        12:39 PM   96914    1.421
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# ...

# %%
empl[empl.Team.isna()]
# Out:
#       First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 10        Louise  Female 1980-08-12         9:01 AM   63241   15.132
# 23           NaN    Male 2012-06-14         4:19 PM  125792    5.042
# 32           NaN    Male 1998-08-21         2:27 PM  122340    6.417
# 91         James     NaN 2005-01-26        11:00 PM  128771    8.309
# 109  Christopher    Male 2000-04-22        10:15 AM   37919   11.449
# 139          NaN  Female 1990-10-03         1:08 AM  132373   10.527
# 199     Jonathan    Male 2009-07-17         8:15 AM  130581   16.736
# 258      Michael    Male 2002-01-24         3:04 AM   43586   12.659
# 290       Jeremy    Male 1988-06-14         6:20 PM  129460   13.657
# 314        Bobby    Male 1996-03-31         5:40 PM  112117    6.338
# 367       Edward    Male 1989-08-04         6:06 AM   66067   10.957
# 382          NaN  Female 1996-04-18         3:57 PM  107024   12.182
# ...

# %%
empl1=empl['Team'].isnull()
empl[empl1]
# Out:
#       First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 10        Louise  Female 1980-08-12         9:01 AM   63241   15.132
# 23           NaN    Male 2012-06-14         4:19 PM  125792    5.042
# 32           NaN    Male 1998-08-21         2:27 PM  122340    6.417
# 91         James     NaN 2005-01-26        11:00 PM  128771    8.309
# 109  Christopher    Male 2000-04-22        10:15 AM   37919   11.449
# 139          NaN  Female 1990-10-03         1:08 AM  132373   10.527
# 199     Jonathan    Male 2009-07-17         8:15 AM  130581   16.736
# 258      Michael    Male 2002-01-24         3:04 AM   43586   12.659
# 290       Jeremy    Male 1988-06-14         6:20 PM  129460   13.657
# 314        Bobby    Male 1996-03-31         5:40 PM  112117    6.338
# 367       Edward    Male 1989-08-04         6:06 AM   66067   10.957
# 382          NaN  Female 1996-04-18         3:57 PM  107024   12.182
# ...

# %%
# 젠더 행의 NaN만 삭제 시킴
empl.dropna(subset = ['Gender'])
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
mask1 = empl["Gender"]=="Male"
mask2 = empl["Gender"]=="Female"
empl[mask1|mask2]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
empl[empl["Gender"].notnull()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
empls=empl["Salary"]>= 60000
empls1=empl["Salary"]<=70000
empl[empls&empls1]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 6         Ruby  Female 1987-08-17         4:20 PM   65476   10.012
# 10      Louise  Female 1980-08-12         9:01 AM   63241   15.132
# 20        Lois     NaN 1995-04-22         7:18 PM   64714    4.934
# 41   Christine     NaN 2015-06-28         1:08 AM   66582   11.308
# ..         ...     ...        ...             ...     ...      ...
# 965  Catherine  Female 1989-09-25         1:31 AM   68164   18.393
# 970      Alice  Female 1988-09-03         8:54 PM   63571   15.397
# 974      Harry    Male 2011-08-30         6:31 PM   67656   16.455
# 978       Sean    Male 1983-01-17         2:23 PM   66146   11.178
# 998      Larry    Male 2013-04-20         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# ...

# %%
empl[empl["Salary"].between(60000,70000)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 6         Ruby  Female 1987-08-17         4:20 PM   65476   10.012
# 10      Louise  Female 1980-08-12         9:01 AM   63241   15.132
# 20        Lois     NaN 1995-04-22         7:18 PM   64714    4.934
# 41   Christine     NaN 2015-06-28         1:08 AM   66582   11.308
# ..         ...     ...        ...             ...     ...      ...
# 965  Catherine  Female 1989-09-25         1:31 AM   68164   18.393
# 970      Alice  Female 1988-09-03         8:54 PM   63571   15.397
# 974      Harry    Male 2011-08-30         6:31 PM   67656   16.455
# 978       Sean    Male 1983-01-17         2:23 PM   66146   11.178
# 998      Larry    Male 2013-04-20         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# ...

# %%
empl['Last Login Time']=empl['Last Login Time'].astype("datetime64[ns]")
empl[empl["Last Login Time"].between("8:20:00","22:00:00")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993 2023-11-02 12:42:00   97308    6.945
# 2        Maria  Female  4/23/1993 2023-11-02 11:17:00  130590   11.858
# 3        Jerry    Male   3/4/2005 2023-11-02 13:00:00  138705    9.340
# 4        Larry    Male  1/24/1998 2023-11-02 16:47:00  101004    1.389
# 6         Ruby  Female  8/17/1987 2023-11-02 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 993       Tina  Female  5/15/1997 2023-11-02 15:53:00   56450   19.040
# 994     George    Male  6/21/2013 2023-11-02 17:47:00   98874    4.479
# 997    Russell    Male  5/20/2013 2023-11-02 12:39:00   96914    1.421
# 998      Larry    Male  4/20/2013 2023-11-02 16:45:00   60500   11.985
# 999     Albert    Male  5/15/2012 2023-11-02 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
empl=pd.read_csv("data/employees.csv", parse_dates=["Start Date", "Last Login Time"])

# %%
empl[empl["Last Login Time"].between("8:30AM","10:00PM")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-11-02 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2023-11-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-11-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-11-02 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2023-11-02 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 993       Tina  Female 1997-05-15 2023-11-02 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2023-11-02 17:47:00   98874    4.479
# 997    Russell    Male 2013-05-20 2023-11-02 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-11-02 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-11-02 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
empl["Team"].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
empl["Team"].nunique("")
# Out:
# 11

# %%
empl["Team"].nunique(dropna= False)
# Out:
# 11

# %%
mac=pd.read_csv("data/bigmac.csv", parse_dates = ["Date"], index_col=["Date","Country"])
mac.head(10)
# Out:
#                            Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                      2.39
#            Australia                      3.74
#            Brazil                         3.35
#            Britain                        4.22
#            Canada                         4.14
#            Chile                          2.94
#            China                          2.68
#            Colombia                       2.43
#            Costa Rica                     4.02
#            Czech Republic                 2.98

# %%
mac.groupby(["Date","Country"]).agg({"Price in US Dollars":max}).head(50)
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71
#            Denmark                        5.99
#            Egypt                          2.38
#            Euro area                      4.84
#            Hong Kong                      1.91
#            Hungary                        3.86
#            Indonesia                      2.24
#            Israel                         3.99
#            Japan                          3.50
# ...

# %%
big = mac["Country"]=="South Korea"
mac[big]
# Out:
#           Date      Country  Price in US Dollars
# 31  2016-01-01  South Korea                 3.59
# 87  2015-07-01  South Korea                 3.76
# 143 2015-01-01  South Korea                 3.78
# 200 2014-07-01  South Korea                 4.00
# 257 2014-01-01  South Korea                 3.47
# 315 2013-07-01  South Korea                 3.43
# 372 2013-01-01  South Korea                 3.41
# 428 2012-07-01  South Korea                 3.21
# 485 2012-01-01  South Korea                 3.19
# 542 2011-07-01  South Korea                 3.50
# 598 2010-07-01  South Korea                 2.82
# 641 2010-01-01  South Korea                 2.98

# %%
mac.sort_index(inplace=True)
mac
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
mac.index.set_names(["D","Location"], inplace=True)
mac
# Out:
#                           Price in US Dollars
# D          Location
# 2016-01-01 Argentina                     2.39
#            Australia                     3.74
#            Brazil                        3.35
#            Britain                       4.22
#            Canada                        4.14
# ...                                       ...
# 2010-01-01 Turkey                        3.83
#            UAE                           2.99
#            Ukraine                       1.83
#            United States                 3.58
#            Uruguay                       3.32
#
# [652 rows x 1 columns]

# %%
btc = pd.read_csv("data/coin_Bitcoin.csv", low_memory = False)
# index_col="Date" 대신 btc.set_index("Date")을 쓸수도 있다.
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
btc.set_index("Date",inplace=True)
btc
# volume 거래량, Open 시가, Close 종가, Marketcap 시가총액
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
btc.High
# 위에 종목 다 나옴
# Out:
# Date
# 2013-04-29 23:59:59      147.488007
# 2013-04-30 23:59:59      146.929993
# 2013-05-01 23:59:59      139.889999
# 2013-05-02 23:59:59      125.599998
# 2013-05-03 23:59:59      108.127998
#                            ...
# 2021-07-02 23:59:59    33939.588699
# 2021-07-03 23:59:59    34909.259899
# 2021-07-04 23:59:59    35937.567147
# 2021-07-05 23:59:59    35284.344430
# 2021-07-06 23:59:59    35038.536363
# Name: High, Length: 2991, dtype: float64

# %%
btc = pd.read_csv("data/coin_Bitcoin.csv")

# %%
btc.High.plot()
# Out:
# <AxesSubplot:>

# %%
btc["High"].plot()
# Out:
# <AxesSubplot:>

# %%
world=pd.read_csv("Data/world-happiness-report-2021.csv")
world
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
world.set_index("Country name",inplace=True)

# %%
world["Healthy life expectancy"]
# Out:
# Country name
# Finland        72.000
# Denmark        72.700
# Switzerland    74.400
# Iceland        73.000
# Netherlands    72.400
#                 ...
# Lesotho        48.700
# Botswana       59.269
# Rwanda         61.400
# Zimbabwe       56.201
# Afghanistan    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
world["Healthy life expectancy"].sort_values(ascending=False).head().plot()
# Out:
# <AxesSubplot:xlabel='Country name'>

# %%
world["Ladder score"]
# Out:
# Country name
# Finland        7.842
# Denmark        7.620
# Switzerland    7.571
# Iceland        7.554
# Netherlands    7.464
#                ...
# Lesotho        3.512
# Botswana       3.467
# Rwanda         3.415
# Zimbabwe       3.145
# Afghanistan    2.523
# Name: Ladder score, Length: 149, dtype: float64

# %%
house=pd.read_csv("Data/kc_house_data.csv")
house.sort_values("price",ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %%
titanic = pd.read_csv("Data/titanic.csv")
titanic["sex"].head(5)
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# 4    female
# Name: sex, dtype: object

# %%
df=titanic.head()

# %%
df.sex=='female'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
titanic[titanic["survived"]==0].sort_values(["pclass","survived"])
# Out:
#       pclass  survived                                             name  \
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7          1         0                           Andrews, Mr. Thomas Jr
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch    ticket     fare    cabin embarked boat  \
# ...

# %%
titanic[titanic["age"]=="18"].sort_values("age")
# Out:
#       pclass  survived                                               name  \
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 676        3         0                       Bjorklund, Mr. Ernst Herbert
# 695        3         0                            Burns, Miss. Mary Delia
# 698        3         0                               Cacic, Mr. Jego Grga
# 717        3         0                        Chronopoulos, Mr. Demetrios
# 719        3         1                           Cohen, Mr. Gurshon 'Gus'
# 786        3         0                     Edvardsson, Mr. Gustaf Hjalmar
# 799        3         0                    Fischer, Mr. Eberhard Thelander
# 665        3         0                              Barbara, Miss. Saiide
# 809        3         0                            Ford, Mr. Edward Watson
# 938        3         0                             Klasen, Mr. Klas Albin
# 1045       3         0            Myhrman, Mr. Pehr Fabian Oliver Malkolm
# ...

# %%
titanic[titanic.pclass !=1]
# 1이 아닌것들만 출력
# 이 코드로도 가능 titanic[titanic["pclass"] !=1]
# Out:
#       pclass  survived                                   name     sex   age  \
# 323        2         0                    Abelson, Mr. Samuel    male    30
# 324        2         1  Abelson, Mrs. Samuel (Hannah Wizosky)  female    28
# 325        2         0         Aldworth, Mr. Charles Augustus    male    30
# 326        2         0             Andrew, Mr. Edgardo Samuel    male    18
# 327        2         0               Andrew, Mr. Frank Thomas    male    25
# ...      ...       ...                                    ...     ...   ...
# 1304       3         0                   Zabour, Miss. Hileni  female  14.5
# 1305       3         0                  Zabour, Miss. Thamine  female     ?
# 1306       3         0              Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                    Zakarian, Mr. Ortin    male    27
# 1308       3         0                     Zimmerman, Mr. Leo    male    29
#
# ...

# %%
best = pd.read_csv("Data/bestsellers.csv")
best
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
best[best["Author"]=="Pete Souza"]
# Out:
#                             Name      Author  User Rating  Reviews  Price  \
# 244  Obama: An Intimate Portrait  Pete Souza          4.9     3192     22
#
#      Year        Genre
# 244  2017  Non Fiction

# %%
best[best["Price"]<10]
# Out:
#                                                   Name           Author  \
# 0                        10-Day Green Smoothie Cleanse         JJ Smith
# 3                               1984 (Signet Classics)    George Orwell
# 8        A Higher Loyalty: Truth, Lies, and Leadership      James Comey
# 9                            A Man Called Ove: A Novel  Fredrik Backman
# 10                           A Man Called Ove: A Novel  Fredrik Backman
# ..                                                 ...              ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
best[best["Price"].between(50,60)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 159         Harry Potter Paperback Box Set (Books 1-7)       J. K. Rowling
# 346  The Book of Basketball: The NBA According to T...        Bill Simmons
#
#      User Rating  Reviews  Price  Year        Genre
# 151          4.9     5867     54  2016  Non Fiction
# 159          4.8    13471     52  2016      Fiction
# 346          4.7      858     53  2009  Non Fiction

# %%
best[(best["Price"] >= 50) & (best["Price"] <= 60)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 159         Harry Potter Paperback Box Set (Books 1-7)       J. K. Rowling
# 346  The Book of Basketball: The NBA According to T...        Bill Simmons
#
#      User Rating  Reviews  Price  Year        Genre
# 151          4.9     5867     54  2016  Non Fiction
# 159          4.8    13471     52  2016      Fiction
# 346          4.7      858     53  2009  Non Fiction

# %%
best[(best["Author"]=="Kristin Hannah")|(best["Author"]=="Andy Weir")|(best["Author"]=="Delia Owens")]
# Out:
#                          Name          Author  User Rating  Reviews  Price  \
# 433               The Martian       Andy Weir          4.7    39459      9
# 437  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 438  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 534   Where the Crawdads Sing     Delia Owens          4.8    87841     15
#
#      Year    Genre
# 433  2015  Fiction
# 437  2015  Fiction
# 438  2016  Fiction
# 534  2019  Fiction

# %%
best[best["Author"].isin(["Kristin Hannah","Andy Weir","Delia Owens"])]
# Out:
#                          Name          Author  User Rating  Reviews  Price  \
# 433               The Martian       Andy Weir          4.7    39459      9
# 437  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 438  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 534   Where the Crawdads Sing     Delia Owens          4.8    87841     15
#
#      Year    Genre
# 433  2015  Fiction
# 437  2015  Fiction
# 438  2016  Fiction
# 534  2019  Fiction

# %%
best[(best["Genre"] == "Non Fiction") & (best["User Rating"] == 4.9)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 174                       Humans of New York : Stories     Brandon Stanton
# 187  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 188  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 189  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 190  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 191  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 192  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 244                        Obama: An Intimate Portrait          Pete Souza
# 431                                 The Magnolia Story         Chip Gaines
# 521                             Unfreedom of the Press       Mark R. Levin
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
best=best[best["User Rating"]<4.5]

# %%
best["Author"].value_counts().head(5).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
house = pd.read_csv("data/kc_house_data.csv", parse_dates=["date"])
house
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df= house["date"].max()- house["date"].min()
df.days
# Out:
# 390

# %%
house["date"].dt.year.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='date'>

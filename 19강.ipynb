# NV    2013    2790136.0
# NY    2013   19651127.0
# OH    2013   11570808.0
# OK    2013    3850568.0
# OR    2013    3930065.0
# PA    2013   12773801.0
# PR    2013    3615086.0
# RI    2013    1051511.0
# SC    2013    4774839.0
# SD    2013     844877.0
# TN    2013    6495978.0
# TX    2013   26448193.0
# USA   2013  316128839.0
# UT    2013    2900872.0
# VA    2013    8260405.0
# VT    2013     626630.0
# WA    2013    6971406.0
# WI    2013    5742713.0
# WV    2013    1854304.0
# WY    2013     582658.0

# %%
pops[pops['population']%2==0]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0
# ...                ...
# WY    2004    509106.0
#       2007    534876.0
#       2010    564222.0
#       2012    576626.0
#       2013    582658.0
#
# [645 rows x 1 columns]

# %%
titanic = pd.read_csv("data/titanic.csv")
titanic['age']=titanic['age'].replace(['?'],[None]).astype('float')
titanic['fare']=titanic['fare'].replace(['?'],[None]).astype('float')
titanic.groupby('sex').agg({'age':['min','max','mean'],'fare':['min','max','mean'],'survived':['mean']})
# Out:
#            age                   fare                       survived
#            min   max       mean   min       max       mean      mean
# sex
# female  0.1667  76.0  28.687071  6.75  512.3292  46.198097  0.727468
# male    0.3333  80.0  30.585233  0.00  512.3292  26.154601  0.190985

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
# [1309 rows x 14 columns]

# %%
titanic.groupby(['pclass','sex']).plot(kind='bar')
# Out:
# pclass  sex
# 1       female    AxesSubplot(0.125,0.11;0.775x0.77)
#         male      AxesSubplot(0.125,0.11;0.775x0.77)
# 2       female    AxesSubplot(0.125,0.11;0.775x0.77)
#         male      AxesSubplot(0.125,0.11;0.775x0.77)
# 3       female    AxesSubplot(0.125,0.11;0.775x0.77)
#         male      AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %%
titanic.groupby(['pclass','sex'])['age'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass,sex'>

# %%
titanic.groupby(['pclass','sex'])['age'].mean().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
titanic.groupby(['pclass','sex'])['age'].mean().unstack('pclass').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
titanic.groupby(['sex','pclass'])['age'].mean().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
titanic.groupby(['sex','survived'])['age'].mean().unstack()
# Out:
# survived          0          1
# sex
# female    25.255208  29.815354
# male      31.516412  26.977778

# %%
titanic.groupby(['sex','survived'])['age'].mean()
# Out:
# sex     survived
# female  0           25.255208
#         1           29.815354
# male    0           31.516412
#         1           26.977778
# Name: age, dtype: float64

# %%
titanic.groupby(['sex','survived'])['age'].mean().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
df=titanic.groupby(['sex','survived'])['age'].mean()
df.unstack().rename(columns={0:"Died",1:"Survived"}).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>
